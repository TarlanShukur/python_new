# %%
tasks = []

tasks.append(input("Lutfen bir gorev giriniz:z"))
tasks.append(input("Lutfen bir gorev giriniz:z"))
tasks.append(input("Lutfen bir gorev giriniz:z"))

# gorevleri listeleme

if tasks:
    print("Gorevler:")
    print(tasks)
else:
    print("liste bos. ") 

# Gorvlerin oncelik sirasini degistirme

if len(tasks) >= 3:
    task_to_move = tasks.pop(0)
    tasks.insert(2, task_to_move)

# Gorevileri listeleme

if tasks:
    print("oncelik degistirildikten sonraki gorevler:")
    print(tasks)
else:
    print("Liste bos")

a = input("Tamamlaycaginiz gorevin numarasini giriniz (Ex: 1, 2, 3 gibi): ")
b = tasks[int(a) - 1]

tasks.remove(b)

print(f"{b} tamamlandi!")

# Gorevileri listeleme

if tasks:
    print(f"{b} tamamlandiktan sonraki gorevler:")
    print(tasks)
else:
    print("Liste bos")
# Out:
# Gorevler:
# ['tenis', 'futbol', 'cinema']
# oncelik degistirildikten sonraki gorevler:
# ['futbol', 'cinema', 'tenis']
# tenis tamamlandi!
# tenis tamamlandiktan sonraki gorevler:
# ['futbol', 'cinema']

# %%
tasks = []

# listeye odev ve sinav ekleyelim

tasks.append(["Matematik Sinavi", "2024-06-30", False])
tasks.append(["Fizik Odevi", "2024-07-30", False])
tasks.append(["Kimya Projesi", "2024-08-30", False])

# sinav ve odev listesini goruntuleme
print("Sinav ve odev listesi:")
print(f"1.Gorev: {tasks[0][0]}","Son teslim tarihi: {tasks[0][1]}, Tamamlandi:{tasks[0][2]}")
print(f"2.Gorev: {tasks[1][0]}","Son teslim tarihi: {tasks[1][1]}, Tamamlandi:{tasks[1][2]}")
print(f"3.Gorev: {tasks[2][0]}","Son teslim tarihi: {tasks[2][1]}, Tamamlandi:{tasks[2][2]}")

# Gorevi tamamlanmis olarak isaretleme
tasks[1][2] = True

# Guncellenmis sinav ve odev listesi
print("Guncellenmis sinav ve odev listesi:")
print(f"1.Gorev: {tasks[0][0]}","Son teslim tarihi: {tasks[0][1]}, Tamamlandi:{tasks[0][2]}")
print(f"2.Gorev: {tasks[1][0]}","Son teslim tarihi: {tasks[1][1]}, Tamamlandi:{tasks[1][2]}")
print(f"3.Gorev: {tasks[2][0]}","Son teslim tarihi: {tasks[2][1]}, Tamamlandi:{tasks[2][2]}")


# Gorev arama
search_task = "Kimya Projesi"
found_task = None

if tasks[0][0] == search_task:
    found_task = tasks[0]
elif tasks[1][0] == search_task:
    found_task = tasks[1]
elif tasks[2][0] == search_task:
    found_task = tasks[2]

# Arama sonuclarini yazdirma
if found_task:
    print("Arama Sonuclari")
    print("----------------------")
    print(f"Gorev: {found_task[0]}, Son teslim tarihi:{found_task[1]},Tamamlandi {found_task[2]}")
else:
    print("Aranan gorev bulunamadi")

# Gorev guncelleme (Matematik sinavi SIT degistirme)

tasks[0][1] = "2024-07-02"
# Guncellenmis sinav ve odev listesi
print("Guncellenmis sinav ve odev listesi:")
print(f"1.Gorev: {tasks[0][0]}","Son teslim tarihi: {tasks[0][1]}, Tamamlandi:{tasks[0][2]}")
print(f"2.Gorev: {tasks[1][0]}","Son teslim tarihi: {tasks[1][1]}, Tamamlandi:{tasks[1][2]}")
print(f"3.Gorev: {tasks[2][0]}","Son teslim tarihi: {tasks[2][1]}, Tamamlandi:{tasks[2][2]}")
# Out:
# Sinav ve odev listesi:
# 1.Gorev: Matematik Sinavi Son teslim tarihi: {tasks[0][1]}, Tamamlandi:{tasks[0][2]}
# 2.Gorev: Fizik Odevi Son teslim tarihi: {tasks[1][1]}, Tamamlandi:{tasks[1][2]}
# 3.Gorev: Kimya Projesi Son teslim tarihi: {tasks[2][1]}, Tamamlandi:{tasks[2][2]}
# Guncellenmis sinav ve odev listesi:
# 1.Gorev: Matematik Sinavi Son teslim tarihi: {tasks[0][1]}, Tamamlandi:{tasks[0][2]}
# 2.Gorev: Fizik Odevi Son teslim tarihi: {tasks[1][1]}, Tamamlandi:{tasks[1][2]}
# 3.Gorev: Kimya Projesi Son teslim tarihi: {tasks[2][1]}, Tamamlandi:{tasks[2][2]}
# Arama Sonuclari
# ----------------------
# Gorev: Kimya Projesi, Son teslim tarihi:2024-08-30,Tamamlandi False
# Guncellenmis sinav ve odev listesi:
# 1.Gorev: Matematik Sinavi Son teslim tarihi: {tasks[0][1]}, Tamamlandi:{tasks[0][2]}
# 2.Gorev: Fizik Odevi Son teslim tarihi: {tasks[1][1]}, Tamamlandi:{tasks[1][2]}
# 3.Gorev: Kimya Projesi Son teslim tarihi: {tasks[2][1]}, Tamamlandi:{tasks[2][2]}

# %%
math_grade = ("Matematik", 
              [float(input("Matematik 1. Yazili notunu girin:")), 
               float(input("Matematik 2. Yazili notunu girin:")),
               float(input("Matematik 3. Yazili notunu girin:"))])
biology_grade = ("Biyoloji", 
              [float(input("Biyoloji 1. Yazili notunu girin:")), 
               float(input("Biyoloji 2. Yazili notunu girin:")),
               float(input("Biyoloji 3. Yazili notunu girin:"))])
history_grade = ("Tarih", 
              [float(input("Tarih 1. Yazili notunu girin:")), 
               float(input("Tarih 2. Yazili notunu girin:")),
               float(input("Tarih 3. Yazili notunu girin:"))])     

# Sinav_notlarinin ortalamasini bulma
math_grade[1].append(sum(math_grade[1]) / len(math_grade[1]))
biology_grade[1].append(sum(biology_grade[1]) / len(biology_grade[1]))
history_grade[1].append(sum(history_grade[1]) / len(history_grade[1]))

# Ogrencilerin aldigi dersleri ve notunu ve gecip gecmedigini ekrana yazdir

print(f"{math_grade[0]} Ders Notu: {math_grade[1][-1]}", "Gecti" if math_grade[1][-1] > 70 else "Kaldi")
print(f"{biology_grade[0]} Ders Notu: {biology_grade[1][-1]}", "Gecti" if biology_grade[1][-1] > 70 else "Kaldi")
print(f"{history_grade[0]} Ders Notu: {history_grade[1][-1]}", "Gecti" if history_grade[1][-1] > 70 else "Kaldi")
# Out:
# Matematik Ders Notu: 70.0 Kaldi
# Biyoloji Ders Notu: 78.33333333333333 Gecti
# Tarih Ders Notu: 79.33333333333333 Gecti

# %%
location_data = (
    ("Ev",(40.7128, -74.0060)),
    ("Is",(51.5074, -0.1278)),
    ("Okul",(3.0522, -118.2437)),
    ("Park",(48.8566, 2.3522))
)

# Konumlari Goruntuleme

print("kaydedilmis Konum:")
print(f"1. Konum: {location_data[0][0]}, Koordinatlar: {location_data[0][1]}")
print(f"1. Konum: {location_data[1][0]}, Koordinatlar: {location_data[1][1]}")
print(f"1. Konum: {location_data[2][0]}, Koordinatlar: {location_data[2][1]}")
print(f"1. Konum: {location_data[3][0]}, Koordinatlar: {location_data[3][1]}")

# Yeni bir konum ekleme

new_location_data = location_data + (("Kutuphane", (37.7749, -122.4194)),)

# Guncellenmis Konumlari Goruntuleme

print("kaydedilmis Konum:")
print(f"1. Konum: {new_location_data[0][0]}, Koordinatlar: {new_location_data[0][1]}")
print(f"1. Konum: {new_location_data[1][0]}, Koordinatlar: {new_location_data[1][1]}")
print(f"1. Konum: {new_location_data[2][0]}, Koordinatlar: {new_location_data[2][1]}")
print(f"1. Konum: {new_location_data[3][0]}, Koordinatlar: {new_location_data[3][1]}")
print(f"1. Konum: {new_location_data[4][0]}, Koordinatlar: {new_location_data[4][1]}")

updated_location_data = (new_location_data[0],("yeni is", (51.50985, -0.118092)),new_location_data[2],new_location_data[3],new_location_data[4])


# Is konumu Guncellenmis Goruntuleme

print("Is konumu guncellendikten sonra:")
print(f"1. Konum: {new_location_data[0][0]}, Koordinatlar: {new_location_data[0][1]}")
print(f"1. Konum: {new_location_data[1][0]}, Koordinatlar: {new_location_data[1][1]}")
print(f"1. Konum: {new_location_data[2][0]}, Koordinatlar: {new_location_data[2][1]}")
print(f"1. Konum: {new_location_data[3][0]}, Koordinatlar: {new_location_data[3][1]}")
print(f"1. Konum: {new_location_data[4][0]}, Koordinatlar: {new_location_data[4][1]}")
# Out:
# kaydedilmis Konum:
# 1. Konum: Ev, Koordinatlar: (40.7128, -74.006)
# 1. Konum: Is, Koordinatlar: (51.5074, -0.1278)
# 1. Konum: Okul, Koordinatlar: (3.0522, -118.2437)
# 1. Konum: Park, Koordinatlar: (48.8566, 2.3522)
# kaydedilmis Konum:
# 1. Konum: Ev, Koordinatlar: (40.7128, -74.006)
# 1. Konum: Is, Koordinatlar: (51.5074, -0.1278)
# 1. Konum: Okul, Koordinatlar: (3.0522, -118.2437)
# 1. Konum: Park, Koordinatlar: (48.8566, 2.3522)
# 1. Konum: Kutuphane, Koordinatlar: (37.7749, -122.4194)
# Is konumu guncellendikten sonra:
# 1. Konum: Ev, Koordinatlar: (40.7128, -74.006)
# 1. Konum: Is, Koordinatlar: (51.5074, -0.1278)
# 1. Konum: Okul, Koordinatlar: (3.0522, -118.2437)
# 1. Konum: Park, Koordinatlar: (48.8566, 2.3522)
# 1. Konum: Kutuphane, Koordinatlar: (37.7749, -122.4194)
